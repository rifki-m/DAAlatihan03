# %%
import datetime as dt
tanggal = dt.date.today()
mahasiswa = ["Muhamad Aulia Rifki", "2023071030", "Informatika", "Desain Analisis Algoritma", str(tanggal), "Universitas Pembangunan Jaya" ]
print(mahasiswa)
# Out:
# ['Muhamad Aulia Rifki', '2023071030', 'Informatika', 'Desain Analisis Algoritma', '2024-09-19', 'Universitas Pembangunan Jaya']

# %%
print("Nim", mahasiswa[1])
print("Universitas", mahasiswa[5])
# Out:
# Nim 2023071030
# Universitas Universitas Pembangunan Jaya

# %%
mahasiswa[1:3]
# Out:
# ['2023071030', 'Informatika']

# %%
print("NIM", mahasiswa[1:2])
# Out:
# NIM ['2023071030']

# %%
print("Prodi", mahasiswa[2:3])
# Out:
# Prodi ['Informatika']

# %%
print("Mata Kuliah Tanggal Berapa", mahasiswa[4:5])
# Out:
# Mata Kuliah Tanggal Berapa ['2024-09-19']

# %%
for aMahasiswa in mahasiswa:
    print(aMahasiswa + " UPJ")
# Out:
# Muhamad Aulia Rifki UPJ
# 2023071030 UPJ
# Informatika UPJ
# Desain Analisis Algoritma UPJ
# 2024-09-19 UPJ
# Universitas Pembangunan Jaya UPJ

# %%
UPJ=("Universitas","Pembangunan","Jaya")
UPJ[0:]
# Out:
# ('Universitas', 'Pembangunan', 'Jaya')

# %%
nested_tuple=(100,(200,400,600),300,(400,800))
nested_tuple[0]
# Out:
# 100

# %%
print(nested_tuple[1])
# Out:
# (200, 400, 600)

# %%
print(nested_tuple[2])
# Out:
# 300

# %%
print(nested_tuple[3])
# Out:
# (400, 800)

# %%
bin_colors ={
    "manual_color": "Yellow",
    "approved_color": "Green",
    "refused_color": "Red"
}
print(bin_colors)
# Out:
# {'manual_color': 'Yellow', 'approved_color': 'Green', 'refused_color': 'Red'}

# %%
bin_colors.get('approved_color')
# Out:
# 'Green'

# %%
bin_colors['approved_color']
# Out:
# 'Green'

# %%
Latihan ={
    "Nama": "Muhamad Aulia Rifki",
    "Nim": "2023071030",
    "Prodi": "Informatika",
    "Universitas": "UPJ"
}
print(Latihan)
# Out:
# {'Nama': 'Muhamad Aulia Rifki', 'Nim': '2023071030', 'Prodi': 'Informatika', 'Universitas': 'UPJ'}

# %%
yellow = {"dandellion","leaves","fire hydrant"}
red = {'leaves',"fire hydrant","blood"}
print(yellow|red)
print(yellow&red)
# Out:
# {'fire hydrant', 'leaves', 'dandellion', 'blood'}
# {'fire hydrant', 'leaves'}

# %%
import pandas as pd
df = pd.DataFrame([
    ['1','Informatika', 50, 30, 20],
    ['2','Sistem Informasi', 55, 30, 25],
    ['3','Teknik Sipil', 40, 30, 10]
]
)

# %%
df.columns = ['No', 'Prodi', 'Mahasiswa', 'Lakilaki', 'Perempuan']
df
# Out:
#   No             Prodi  Mahasiswa  Lakilaki  Perempuan
# 0  1       Informatika         50        30         20
# 1  2  Sistem Informasi         55        30         25
# 2  3      Teknik Sipil         40        30         10

# %%
df[['Prodi', 'Mahasiswa']]
# Out:
#               Prodi  Mahasiswa
# 0       Informatika         50
# 1  Sistem Informasi         55
# 2      Teknik Sipil         40

# %%
df.iloc[1:3,:]
# Out:
#   No             Prodi  Mahasiswa  Lakilaki  Perempuan
# 1  2  Sistem Informasi         55        30         25
# 2  3      Teknik Sipil         40        30         10

# %%
import numpy as np
myMatrix = np.array([[100, 200, 300], [700, 600, 500], [900, 1000, 800]])
print(myMatrix)
# Out:
# [[ 100  200  300]
#  [ 700  600  500]
#  [ 900 1000  800]]

# %%
transposed_matrix = list(map(list, zip(*myMatrix)))
print(transposed_matrix)
# Out:
# [[100, 700, 900], [200, 600, 1000], [300, 500, 800]]

# %%
print(type(myMatrix))
# Out:
# <class 'numpy.ndarray'>
